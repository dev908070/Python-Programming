# %%
order = []
baselist = []
stylelist= []
toppinglist= []

pizza ={
    'category':
        {
            'crust base':
        {          'thin':4.00,
                   'thick':6.50,
                   'woodfired':8.50,
       
        }
    ,     
            'cheese style':
        {         'chedder':5,
                  'colby':5,
                  'edam':5,
                  'emmentel':5,
                  'gruyere':5 ,
                  'mozzarela':5,
                  'provolone':5,
                  'picotta':5,
            
        }
        ,
             'topping choice':
        
        {              'tomato':0.75,
                       'mushrooms':0.75,
                       'pepperoni':0.50,
                       'onion':0.50,
                       'black olives':0.75,
                       'green peppers':0.50,
                       'anchovice':0.25,
                       'garlic':0.50,
                       'ham':1.50,
                       'bacon':1.25,
          }
          }
        }


qty =int(input("how many pizza you want to order ="))
pizzaqty = qty+1
temp =0
while(True):
    temp=temp+1
    if pizzaqty == temp:
        break
    for values in pizza['category']:
        print("----",values)
        
    print("please select step 1")
    
    for values in pizza['category']['crust base']:
        print("------",values)
    print("step 1:")
    Base = input("please select your base")
    baselist.append(Base)
    
    for values in pizza['category']['cheese style']:
        print("-----",values)
    print("step 2:")
    style = input("please select your style")
    stylelist.append(style)
    
    for values in pizza['category']['topping choice']:
        print("------",values)
    print("step 3:")
    topping = input("please select your topping choice:")
    toppinglist.append(topping)
    
    print(temp,"your order selected")
    
print("No\tBase\tCheesestyle\tTopping\tPrice")
for v in range(len(baselist)):
    
    print(v+1,end="\t")
    print(baselist[v], end="\t")
    print(stylelist[v], end="\t\t")
    print(toppinglist[v], end="\t\t\t")
    print(pizza['category']['crust base'][baselist[v]] +pizza['category']['cheese style'][stylelisyt[v]] +pizza['category']['topping choice'][toppinglist[v]],end="\t \t \t \t")
    
    total=pizza['category']['crust base'][baselist[v]] +pizza['category']['cheese style'][stylelisyt[v]] +pizza['category']['topping choice'][toppinglist[v]]
    order.append(total)
    
    
    print()
    
    
odrtotal=0    
for o in order:
    odrtotal=odrtotal=o
print(""*50)
print("Total:\t\t\t\t\t\t\t\t",end="")
print(odrtotal,end="")
# Out:
# how many pizza you want to order =4
# ---- crust base
# ---- cheese style
# ---- topping choice
# please select step 1
# ------ thin
# ------ thick
# ------ woodfired
# step 1:
# please select your basewoodfired
# ----- chedder
# ----- colby
# ----- edam
# ----- emmentel
# ----- gruyere
# ----- mozzarela
# ----- provolone
# ----- picotta
# step 2:
# please select your stylecolby
# ------ tomato
# ------ mushrooms
# ------ pepperoni
# ------ onion
# ------ black olives
# ------ green peppers
# ------ anchovice
# ------ garlic
# ------ ham
# ------ bacon
# step 3:
# please select your topping choice:onion
# 1 your order selected
# ---- crust base
# ---- cheese style
# ---- topping choice
# please select step 1
# ------ thin
# ------ thick
# ------ woodfired
# step 1:

# %%
Name=str(input(" Name:-"))
Name.isalpha()
# Out:
#  Name:-123
# False
